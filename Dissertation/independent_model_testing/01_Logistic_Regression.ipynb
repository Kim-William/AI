# %%
import sys
import os
import numpy as np
from sklearn.model_selection import RandomizedSearchCV

sys.path.append(os.path.abspath(os.path.join(os.path.dirname('textpreprocessor.py'), '..')))

# %%
# Importing necessary libraries
from cuml.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
from textpreprocessor import TextPreprocessor

# Initialize the Text Pre Processor class
processor = TextPreprocessor()

# Load data
df_train, df_test = processor.load_data(1000)

# Preprocess data
df_train = processor.preprocess(df_train)
df_test = processor.preprocess(df_test)

# Split data
X_train, y_train= processor.split_data(df_train)
X_test, y_test = processor.split_data(df_test)

X_train_tfidf, X_test_tfidf = processor.vectorize_text(X_train, X_test)
# Out:
# 2024-09-23 23:07:21.595910: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-23 23:07:21.604889: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-23 23:07:21.607456: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-23 23:07:21.614742: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-23 23:07:22.198294: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
X_train
# Out:
# 2079998    This product consists of a piece of thin flexi...
# 1443106    Even on the lowest setting, the toast is too d...
# 3463669    I enjoyed this disc. The video is stunning. I ...
# 2914699    The authors pretend that parents neither die n...
# 1603231    Might as well just use a knife, this product h...
#                                  ...
# 1451551    I think this book is a all right type of book....
# 3544634    This iron cuts my ironiong time in half. It is...
# 595288     I have looked and analised the book, and compa...
# 1852088    The same work conducted by Klempeler with Phil...
# 282175     Very informative and well written. When I star...
# Name: review, Length: 1000, dtype: object

# %%
X_test
# Out:
# 23218     I must preface this by saying that I am not re...
# 20731     As a big time, long term Trevanian fan, I was ...
# 39555     This album is hot as it wants to be. However C...
# 147506    I read this book when I was in elementary scho...
# 314215    Although this book is touted on several Anusar...
#                                 ...
# 249364    This is NOT a steam cleaner. No steam involved...
# 275716    boring ,no fun game, my 5 year old daughter ha...
# 218447    Beyond the Pale is the latest album from comed...
# 394362    The flash drive is fast in copying files and d...
# 174433    Very disappointing, the only good thing in it ...
# Name: review, Length: 200, dtype: object

# %%
# Model building
# Using Logistic Regression for sentiment classification
model = LogisticRegression()
model.fit(X_train_tfidf, y_train)
# Out:
# LogisticRegression()

# %%
# Making predictions
y_pred = model.predict(X_test_tfidf)

# %%
# Model evaluation
accuracy = accuracy_score(y_test, y_pred)
print(f"Model Accuracy: {accuracy * 100:.2f}%")
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Model Accuracy: 82.50%
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.80      0.85      0.82        97
#            1       0.85      0.81      0.83       103
#
#     accuracy                           0.82       200
#    macro avg       0.83      0.83      0.82       200
# weighted avg       0.83      0.82      0.83       200
